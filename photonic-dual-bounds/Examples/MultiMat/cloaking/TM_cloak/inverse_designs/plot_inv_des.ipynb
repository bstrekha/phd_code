# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
design_file = 'results/cloak_Qabs_sweep_rand_gpr50_circle_2sides_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_Qabs5.0e+05_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_vac_gpr50_circle_2sides_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_design.png', bbox_inches='tight')

# %%
design_file = 'results/cloak_Qabs_sweep_half_gpr50_circle_2sides_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_Qabs5.0e+05_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_vac_gpr50_circle_2sides_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_design.png', bbox_inches='tight')

# %%
design_file = 'results/cloak_Qabs_sweep_rand_gpr50_circle_2sides_Rinner0d25_Router0d75_chif-4+1j_chid5+1e-3j_Qabs5.0e+05_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_vac_gpr50_circle_2sides_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_design.png', bbox_inches='tight')

# %%
design_file = 'results/cloak_Qabs_sweep_half_gpr50_circle_2sides_Rinner0d25_Router0d75_chif-4+1j_chid5+1e-3j_Qabs5.0e+05_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_vac_gpr50_circle_2sides_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_design.png', bbox_inches='tight')

# %%
design_file = 'results/cloak_Qabs_sweep_rand_gpr50_square_Linner0d5_Louter1d5_chif4+1e-3j_chid3+1e-3j_Qabs5.0e+06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_rand_gpr50_square_Linner0d5_Louter1d5_chif4+1e-3j_chid5+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_design.png', bbox_inches='tight')

# %%
design_file = 'results/cloak_sweepchidIm_rand_gpr50_chif10+1e-1j_chidRe8_Rinner0d25_Router0d75_chidIm1.00000000e-06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_sweepchidIm_vac_gpr50_chif10+1e-1j_chidRe8_Rinner0d25_Router0d75_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_design.png', bbox_inches='tight')

# %%
design_file = 'results/cloak_sweepchidIm_rand_gpr50_chif10+1e-1j_chidRe12_Rinner0d25_Router0d75_chidIm1.00000000e-06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_sweepchidIm_vac_gpr50_chif10+1e-1j_chidRe12_Rinner0d25_Router0d75_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_design.png', bbox_inches='tight')

# %%
design_file = 'results/cloak_1by1_chif4+1e-3j_chid2+1e-3j_Qabs5.0e+05_L1.0_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_1by1_chif4+1e-3j_chid2+1e-3j_L1.0_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_design.png', bbox_inches='tight')

# %%
design_file = 'results/cloak_Rinner0d25_Router0d75_chif4+1e-3j_chid2+1e-3j_Qabs5.0e+02_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Rinner0d25_Router0d75_chif4+1e-3j_chid2+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_design.png', bbox_inches='tight')

# %%
design_file = 'results/cloak_Rinner0d25_Router0d75_chif-4+1j_chid4+1e-3j_Qabs5.0e+06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Rinner0d25_Router0d75_chif4+1e-3j_chid2+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_Rinner0d25_Router0d75_chif-4+1j_chid4+1e-3j_Qabs5.0e+06_L1.5_optdof.pdf', bbox_inches='tight')

# %%
design_file = 'results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof.pdf', bbox_inches='tight')

# %%
design_file = 'results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe5+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe5+1e-3j_Qabs5.0e+06_L1.5_optdof.pdf', bbox_inches='tight')

# %%
design_file = 'results/cloak_Qabs_sweep_vac_gpr50_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe4+1e-3j_chidRe3+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof.pdf', bbox_inches='tight')

# %%
design_file = 'results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe4+1e-3j_chidRe5+1e-3j_Qabs5.0e+06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe4+1e-3j_chidRe5+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(7,3))
bounds = np.load('results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.npy')
omegas = np.load('results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum_omegas.npy')

plt.plot(omegas/2/np.pi, bounds)
plt.axhline(y = 1.0, color = 'black', linestyle = 'dotted')
plt.yscale('log')
plt.xlabel('$\omega/\omega_{0}$')
plt.ylabel('$P_{ext,clk+obj}/P_{ext,obj}$')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.pdf', bbox_inches='tight')

# %%
bounds = np.load('results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.npy')
omegas = np.load('results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum_omegas.npy')

plt.plot(omegas/2/np.pi, bounds)
plt.axhline(y = 1.0, color = 'black', linestyle = 'dotted')
plt.yscale('log')
plt.xlabel('$\omega/\omega_{0}$')
plt.ylabel('$P_{ext,clk+obj}/P_{ext,obj}$')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(7,3))
bounds = np.load('results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.npy')
omegas = np.load('results/cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum_omegas.npy')

plt.plot(omegas/2/np.pi, bounds)
plt.axhline(y = 1.0, color = 'black', linestyle = 'dotted')
plt.yscale('log')
plt.xlabel('$\omega/\omega_{0}$')
plt.ylabel('$P_{ext,clk+obj}/P_{ext,obj}$')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(7,3))
bounds = np.load('results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.npy')
omegas = np.load('results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum_omegas.npy')

plt.plot(omegas/2/np.pi, bounds)
plt.axhline(y = 1.0, color = 'black', linestyle = 'dotted')
plt.yscale('log')
plt.xlabel('$\omega/\omega_{0}$')
plt.ylabel('$P_{ext,clk+obj}/P_{ext,obj}$')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe4+1e-3j_chidRe5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(7,3))
bounds = np.load('results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.npy')
omegas = np.load('results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum_omegas.npy')

plt.plot(omegas/2/np.pi, bounds)
plt.axhline(y = 1.0, color = 'black', linestyle = 'dotted')
plt.yscale('log')
plt.xlabel('$\omega/\omega_{0}$')
plt.ylabel('$P_{ext,clk+obj}/P_{ext,obj}$')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(7,3))

bounds = np.load('results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.npy')
omegas = np.load('results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum_omegas.npy')

plt.plot(omegas/2/np.pi, bounds)

bounds = np.load('results/cloak_Qabs_sweep_vac_gpr50_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.npy')
omegas = np.load('results/cloak_Qabs_sweep_vac_gpr50_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum_omegas.npy')

plt.plot(omegas/2/np.pi, bounds, linestyle='dashed')

plt.axhline(y = 1.0, color = 'black', linestyle = 'dotted')
plt.yscale('log')
plt.xlabel('$\omega/\omega_{0}$')
plt.ylabel('$P_{ext,clk+obj}/P_{ext,obj}$')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_dielectric+metal_Qabs5.0e+06_L1.5_optdof_spectrum.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(7,3))

bounds = np.load('results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.npy')
omegas = np.load('results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum_omegas.npy')

plt.plot(omegas/2/np.pi, bounds, label='$\chi_{o} = -4 + i$')

bounds = np.load('results/cloak_Qabs_sweep_vac_gpr50_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum.npy')
omegas = np.load('results/cloak_Qabs_sweep_vac_gpr50_Rinner0d25_Router0d75_chif4+1e-3j_chid5+1e-3j_Qabs5.0e+06_L1.5_optdof_spectrum_omegas.npy')

plt.plot(omegas/2/np.pi, bounds, linestyle='dashed', label='$\chi_{o} = 4 + 10^{-3}i$')

plt.axhline(y = 1.0, color = 'black', linestyle = 'dotted')
plt.yscale('log')
plt.xlabel('$\omega/\omega_{0}$')
plt.ylabel('$P_{ext,clk+obj}/P_{ext,obj}$')
plt.legend()
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_dielectric+metal_Qabs5.0e+06_L1.5_optdof_spectrum.pdf', bbox_inches='tight')

# %%
design_file = 'results/cloak_Qabs_sweep_gpr25_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_gpr25_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_Qabs_sweep_gpr50_Rinner0d25_Router0d75_chifRe-4+1j_chidRe3+1e-3j_Qabs5.0e+06_L1.5_optdof.pdf', bbox_inches='tight')

# %%
################
design_file = 'results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid3+1e-3j_Qabs5.0e+06_L1.5_optdof.npy'
design = np.load(design_file)

background = np.zeros_like(design)
background_file = 'results/cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid3+1e-3j_L1.5_backgrounddof.npy'
background = np.load(background_file)
plt.figure(figsize=((7,7)))
plt.imshow(design + background/2,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.savefig('cloak_Qabs_sweep_rand_gpr50_Rinner0d25_Router0d75_chif-4+1j_chid3+1e-3j_Qabs5.0e+06_L1.5_optdof.pdf', bbox_inches='tight')
