# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
design_file = 'TMLDOSmin4+1e-1j_Qabs1e-1to1e6_periodicfullspace_period0p35_maxeval1000_Wfunc_normalized_vacstart_Qabs1.0e+05_L10.0_optdof.txt'
design = np.loadtxt(design_file)
L = int(np.sqrt(len(design)))
design = design.reshape(L, L)
plt.figure(figsize=((7,7)))
plt.imshow(design,cmap='Greys')
plt.xticks([])
plt.yticks([])
plt.savefig('minLDOS_TM_chi4+1jQsrc_period1lambda.png', bbox_inches='tight')
